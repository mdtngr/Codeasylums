# %%
import pandas as pd

df = pd.read_csv('./Iris_Data.csv')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
sns.set_style('whitegrid')
# sns.pairplot(df,hue='Species')
sns.FacetGrid(df,hue='species',height=5).map(sns.distplot,'petal_length').add_legend();

# %%
import matplotlib.pyplot as plt

plt.plot(df['sepal_length'],df['sepal_width'],'ro',markersize=3)
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.violinplot(x='Species',y='PetalLengthCm',data=df)
plt.plot()
# Out:
# []

# %%
sns.pairplot(df,hue='species')

# %%
from sklearn.model_selection import train_test_split
train,test = train_test_split(df,test_size=0.3,random_state=3)

# %%
df2=train[train['species']!='Iris-setosa']

# %%
plt.figure(figsize=(20,10))
#plt.plot(train.SepalLengthCm[(train['Species']=='Iris-setosa')],train.SepalWidthCm[(train['Species']=='Iris-setosa')],'ro',markersize=10)
plt.plot(train.PetalLengthCm[(train['Species']=='Iris-setosa')],train.PetalWidthCm[(train['Species']=='Iris-setosa')],'ro',markersize=10)

#plt.plot(train.SepalLengthCm[(train['Species']=='Iris-versicolor')],train.SepalWidthCm[(train['Species']=='Iris-versicolor')],'bo',markersize=10)
plt.plot(train.PetalLengthCm[(train['Species']=='Iris-versicolor')],train.PetalWidthCm[(train['Species']=='Iris-versicolor')],'go',markersize=10)

#plt.plot(train.SepalLengthCm[(train['Species']=='Iris-virginica')],train.SepalWidthCm[(train['Species']=='Iris-virginica')],'bo',markersize=10)
plt.plot(train.PetalLengthCm[(train['Species']=='Iris-virginica')],train.PetalWidthCm[(train['Species']=='Iris-virginica')],'bo',markersize=10)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-0437420f4bd6> in <module>
#       1 plt.figure(figsize=(20,10))
#       2 #plt.plot(train.SepalLengthCm[(train['Species']=='Iris-setosa')],train.SepalWidthCm[(train['Species']=='Iris-setosa')],'ro',markersize=10)
# ----> 3 plt.plot(train.PetalLengthCm[(train['Species']=='Iris-setosa')],train.PetalWidthCm[(train['Species']=='Iris-setosa')],'ro',markersize=10)
#       4
#       5 #plt.plot(train.SepalLengthCm[(train['Species']=='Iris-versicolor')],train.SepalWidthCm[(train['Species']=='Iris-versicolor')],'bo',markersize=10)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'PetalLengthCm'

# %%
sl=df[['sepal_length']]
sw=df[['sepal_width']]
pl=df[['petal_width']]
pw=df[['petal_width']]
sl.plot.kde()
sw.plot.kde()
pl.plot.kde()
pw.plot.kde()

# %%
train_x=train[['sepal_length','sepal_width','petal_length','petal_width']]
train_y=train.species

test_x=test[['sepal_length','sepal_width','petal_length','petal_width']]
test_y=test.species

# %%
#Decision tree
from sklearn import tree
from sklearn.metrics import confusion_matrix
clf = tree.DecisionTreeClassifier()
clf=clf.fit(train_x,train_y)
clf.predict_proba(test_x)
clf.predict(test_x)
clf.score(df[['sepal_length','sepal_width','petal_length','petal_width']],df.species)
confusion_matrix(clf.predict(test_x),test_y)
# Out:
# array([[17,  0,  0],
#        [ 0, 13,  1],
#        [ 0,  1, 13]])

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
neigh = KNeighborsClassifier(n_neighbors=1)
neigh.fit(train_x,train_y)
neigh.predict(test_x)
neigh.predict_proba(test_x)
neigh.score(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']],df.Species)
confusion_matrix(neigh.predict(test_x),test_y)
# Out:
# array([[17,  0,  0],
#        [ 0, 13,  1],
#        [ 0,  1, 13]])

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df[df.SepalLengthCm<5.1]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 22    23            4.6           3.6            1.0           0.2
# 24    25            4.8           3.4            1.9           0.2
# 25    26            5.0           3.0            1.6           0.2
# 26    27            5.0           3.4            1.6           0.4
# 29    30            4.7           3.2            1.6           0.2
# 30    31            4.8           3.1            1.6           0.2
# 34    35            4.9           3.1            1.5           0.1
# 35    36            5.0           3.2            1.2           0.2
# 37    38            4.9           3.1            1.5           0.1
# 38    39            4.4           3.0            1.3           0.2
# 40    41            5.0           3.5            1.3           0.3
# 41    42            4.5           2.3            1.3           0.3
# 42    43            4.4           3.2            1.3           0.2
# 43    44            5.0           3.5            1.6           0.6
# 45    46            4.8           3.0            1.4           0.3
# 47    48            4.6           3.2            1.4           0.2
# 49    50            5.0           3.3            1.4           0.2
# 57    58            4.9           2.4            3.3           1.0
# 60    61            5.0           2.0            3.5           1.0
# 93    94            5.0           2.3            3.3           1.0
# 106  107            4.9           2.5            4.5           1.7
#
#              Species
# 1        Iris-setosa
# 2        Iris-setosa
# 3        Iris-setosa
# 4        Iris-setosa
# 6        Iris-setosa
# 7        Iris-setosa
# 8        Iris-setosa
# 9        Iris-setosa
# 11       Iris-setosa
# 12       Iris-setosa
# 13       Iris-setosa
# 22       Iris-setosa
# 24       Iris-setosa
# 25       Iris-setosa
# 26       Iris-setosa
# 29       Iris-setosa
# 30       Iris-setosa
# 34       Iris-setosa
# 35       Iris-setosa
# 37       Iris-setosa
# 38       Iris-setosa
# 40       Iris-setosa
# 41       Iris-setosa
# 42       Iris-setosa
# 43       Iris-setosa
# 45       Iris-setosa
# 47       Iris-setosa
# 49       Iris-setosa
# 57   Iris-versicolor
# 60   Iris-versicolor
# 93   Iris-versicolor
# 106   Iris-virginica

# %%
df.boxplot(column=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])

# %%
df[df.SepalLengthCm>7.5]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 105  106            7.6           3.0            6.6           2.1
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 122  123            7.7           2.8            6.7           2.0
# 131  132            7.9           3.8            6.4           2.0
# 135  136            7.7           3.0            6.1           2.3
#
#             Species
# 105  Iris-virginica
# 117  Iris-virginica
# 118  Iris-virginica
# 122  Iris-virginica
# 131  Iris-virginica
# 135  Iris-virginica

# %%
df1 = df.drop(columns='Species')
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 15    16            5.7           4.4            1.5           0.4
# 16    17            5.4           3.9            1.3           0.4
# 17    18            5.1           3.5            1.4           0.3
# 18    19            5.7           3.8            1.7           0.3
# 19    20            5.1           3.8            1.5           0.3
# 20    21            5.4           3.4            1.7           0.2
# 21    22            5.1           3.7            1.5           0.4
# 22    23            4.6           3.6            1.0           0.2
# 23    24            5.1           3.3            1.7           0.5
# 24    25            4.8           3.4            1.9           0.2
# 25    26            5.0           3.0            1.6           0.2
# 26    27            5.0           3.4            1.6           0.4
# 27    28            5.2           3.5            1.5           0.2
# 28    29            5.2           3.4            1.4           0.2
# 29    30            4.7           3.2            1.6           0.2
# ..   ...            ...           ...            ...           ...
# 120  121            6.9           3.2            5.7           2.3
# 121  122            5.6           2.8            4.9           2.0
# 122  123            7.7           2.8            6.7           2.0
# 123  124            6.3           2.7            4.9           1.8
# 124  125            6.7           3.3            5.7           2.1
# 125  126            7.2           3.2            6.0           1.8
# 126  127            6.2           2.8            4.8           1.8
# 127  128            6.1           3.0            4.9           1.8
# 128  129            6.4           2.8            5.6           2.1
# 129  130            7.2           3.0            5.8           1.6
# 130  131            7.4           2.8            6.1           1.9
# 131  132            7.9           3.8            6.4           2.0
# 132  133            6.4           2.8            5.6           2.2
# 133  134            6.3           2.8            5.1           1.5
# 134  135            6.1           2.6            5.6           1.4
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
#K Means
from sklearn.model_selection import train_test_split
train,test = train_test_split(df1,test_size=0.3,random_state=3)
train_x=train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
train_y=train.Species

test_x=test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
test_y=test.Species

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,random_state=0).fit(train_x)
kmeans.predict(test_x)
# Out:
# array([1, 1, 1, 1, 1, 0, 2, 1, 0, 2, 2, 1, 2, 2, 0, 1, 2, 0, 2, 1, 2, 0,
#        0, 2, 1, 0, 0, 2, 2, 2, 1, 1, 0, 2, 1, 1, 0, 1, 0, 2, 0, 2, 1, 1,
#        2], dtype=int32)
